# %% [markdown]
# ## CHAT COMPLETIONS API MANUAL

# %%
import os
from dotenv import load_dotenv
from scraper import fetch_page_content
from IPython.display import Markdown, display

# %%
# Load environment variables from .env file
load_dotenv(override=True)
api_key = os.getenv("OLLAMA_API_KEY")
api_model = os.getenv("OLLAMA_MODEL")
base_url = os.getenv("OLLAMA_BASE_URL")

# Check if the API key and model are set
if not api_key or not api_model or not base_url:
    raise ValueError("Please set the OLLAMA_API_KEY, OLLAMA_MODEL, and OLLAMA_BASE_URL environment variables in your .env file.")
elif not api_key.startswith("ollama") or not api_model.startswith("llama"):
    raise ValueError("The OLLAMA_API_KEY/OLLAMA_MODEL should start with 'ollama'/'llama'. Please check your .env file.")
else:
    print("Environment variables loaded successfully.")
# Out:
# Environment variables loaded successfully.

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": api_model,
    "messages": [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"}
    ]
}

print("Sending request to Ollama API with payload:\n", payload)
# Out:
# Sending request to Ollama API with payload:
#  {'model': 'llama3.2', 'messages': [{'role': 'system', 'content': 'You are a helpful assistant.'}, {'role': 'user', 'content': 'What is the capital of France?'}]}

# %%
response = requests.post(f"{base_url}/chat/completions", headers=headers, json=payload)

print(response.json())
# Out:
# {'id': 'chatcmpl-611', 'object': 'chat.completion', 'created': 1776083733, 'model': 'llama3.2', 'system_fingerprint': 'fp_ollama', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'The capital of France is Paris.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 38, 'completion_tokens': 8, 'total_tokens': 46}}

# %%
print(response.json()["choices"][0]["message"]["content"])
# Out:
# The capital of France is Paris.

# %% [markdown]
# ## CHAT COMPLETIONS API USING OPENAI SDK AS A WRAPPER

# %%
from openai import OpenAI
client = OpenAI(base_url=base_url, api_key=api_key)

print("Sending request to Ollama API using OpenAI client:", client)
# Out:
# Sending request to Ollama API using OpenAI client: <openai.OpenAI object at 0x0000025D5B0EB230>

# %%
# Get a fun fact about India

res = client.chat.completions.create(
    model=api_model,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Give me a fun fact about India."}
    ]
)
print(res.choices[0].message.content)
# Out:
# Here's one:
#
# Did you know that the smallest country in the world, the Maldives, is actually closer to India than most people realize? In fact, if you were to look at a map, you'd think they're separated by a lot of water. But surprisingly, on very rare and specific circumstances during low tide, when the Indian Ocean's water level drops, you can technically walk from the coast of India directly into the Maldives! Isn't that a cool (and somewhat unusual) fact about our beautiful country?
