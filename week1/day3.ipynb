# %% [markdown]
# ### BROCHURE FOR A COMPANY TO BE USED FOR PROSPECTIVE CLIENTS, INVESTORS AND POTENTIAL RECRUITS

# %% [markdown]
# ##### STEP 1: FIGURE OUT WHICH LINKS ARE RELEVANT IN WEBPAGE USING OLLAMA

# %%
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_page_content, fetch_page_links
from openai import OpenAI

# %%
load_dotenv(override=True)
key = os.getenv("OLLAMA_API_KEY")
model = os.getenv("OLLAMA_MODEL")
url = os.getenv("OLLAMA_BASE_URL")

if key and key.startswith('ollama') and len(key) > 0:
    print("API Key is set correctly.")
else:
    print("API Key is not set correctly. Please check your .env file.")

client = OpenAI(base_url=url, api_key=key)
# Out:
# API Key is set correctly.

# %%
link = fetch_page_links("https://edition.cnn.com")
md_text = "\n".join([f"{i+1}. [{url}]({url})" for i, url in enumerate(link)])
display(Markdown(md_text))
# Out:
# 1. [https://edition.cnn.com/sport/tennis](https://edition.cnn.com/sport/tennis)
# 2. [https://edition.cnn.com/science/life](https://edition.cnn.com/science/life)
# 3. [https://edition.cnn.com/business/investing](https://edition.cnn.com/business/investing)
# 4. [https://twitter.com/CNN](https://twitter.com/CNN)
# 5. [https://edition.cnn.com](https://edition.cnn.com)
# 6. [https://edition.cnn.com/sports](https://edition.cnn.com/sports)
# 7. [https://edition.cnn.com/games](https://edition.cnn.com/games)
# 8. [https://edition.cnn.com/cnn10](https://edition.cnn.com/cnn10)
# 9. [https://edition.cnn.com/science/unearthed](https://edition.cnn.com/science/unearthed)
# 10. [https://edition.cnn.com/audio](https://edition.cnn.com/audio)
# 11. [https://edition.cnn.com/audio/podcasts/5-things](https://edition.cnn.com/audio/podcasts/5-things)
# 12. [https://edition.cnn.com/health/life-but-better/sleep](https://edition.cnn.com/health/life-but-better/sleep)
# 13. [https://cnnespanol.cnn.com/?hpt=header_edition-picker](https://cnnespanol.cnn.com/?hpt=header_edition-picker)
# 14. [https://edition.cnn.com/world/asia](https://edition.cnn.com/world/asia)
# 15. [https://edition.cnn.com/world/middle-east](https://edition.cnn.com/world/middle-east)
# 16. [https://edition.cnn.com/election/2026](https://edition.cnn.com/election/2026)
# 17. [https://edition.cnn.com/tv/all-shows](https://edition.cnn.com/tv/all-shows)
# 18. [https://edition.cnn.com/world/india](https://edition.cnn.com/world/india)
# 19. [https://edition.cnn.com/style/beauty](https://edition.cnn.com/style/beauty)
# 20. [https://edition.cnn.com/profiles/cnn-leadership](https://edition.cnn.com/profiles/cnn-leadership)
# 21. [https://edition.cnn.com/entertainment/celebrities](https://edition.cnn.com/entertainment/celebrities)
# 22. [https://edition.cnn.com/accessibility](https://edition.cnn.com/accessibility)
# 23. [https://edition.cnn.com/markets/premarkets](https://edition.cnn.com/markets/premarkets)
# 24. [https://edition.cnn.com/interactive/call-to-earth](https://edition.cnn.com/interactive/call-to-earth)
# 25. [https://edition.cnn.com/health](https://edition.cnn.com/health)
# 26. [https://instagram.com/CNN](https://instagram.com/CNN)
": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
def get_links_attached_to_user_prompt(url):
    user_prompt = f"""
    Here is the list of links on the website {url} -
    Please decide which of these are relevant web links for a brochure about the company,
    respond with the full https URL in JSON format.
    Do not include Terms of Service, Privacy, email links.

    Links (some might be relative links):

    """

    links = fetch_page_links(url)
    user_prompt += "\n".join([f"- {link}" for link in links])
    return user_prompt

# %%
print(get_links_attached_to_user_prompt("https://edition.cnn.com"))
# Out:
#     Here is the list of links on the website https://edition.cnn.com -
#     Please decide which of these are relevant web links for a brochure about the company,
#     respond with the full https URL in JSON format.
#     Do not include Terms of Service, Privacy, email links.
#
#     Links (some might be relative links):
#
#     - https://edition.cnn.com/sport/tennis
# - https://edition.cnn.com/science/life
# - https://edition.cnn.com/business/investing
# - https://twitter.com/CNN
# - https://edition.cnn.com
# - https://edition.cnn.com/sports
# - https://edition.cnn.com/games
# - https://edition.cnn.com/cnn10
# - https://edition.cnn.com/science/unearthed
# - https://edition.cnn.com/audio
# - https://edition.cnn.com/audio/podcasts/5-things
# - https://edition.cnn.com/health/life-but-better/sleep
# - https://cnnespanol.cnn.com/?hpt=header_edition-picker
# - https://edition.cnn.com/world/asia
# - https://edition.cnn.com/world/middle-east
# - https://edition.cnn.com/election/2026
# - https://edition.cnn.com/tv/all-shows
# - https://edition.cnn.com/world/india
# - https://edition.cnn.com/style/beauty
# - https://edition.cnn.com/profiles/cnn-leadership
# - https://edition.cnn.com/entertainment/celebrities
# - https://edition.cnn.com/accessibility
# - https://edition.cnn.com/markets/premarkets
# - https://edition.cnn.com/interactive/call-to-earth
# - https://edition.cnn.com/health
# - https://instagram.com/CNN
# - https://edition.cnn.com/style/arts
# - https://edition.cnn.com/health/life-but-better/food
# - https://edition.cnn.com/markets/after-hours
# - https://edition.cnn.com/terms
# - https://edition.cnn.com/newsletters
# - https://edition.cnn.com/sport
# - https://edition.cnn.com/
# - https://edition.cnn.com/about
# - https://edition.cnn.com/business/markets/nightcap
# - https://edition.cnn.com/live-tv
# - https://edition.cnn.com/style/videos
# - https://edition.cnn.com/sport/soccer
# - https://edition.cnn.com/audio/podcasts/all-there-is-with-anderson-cooper
# - https://www.linkedin.com/company/cnn
# - https://edition.cnn.com/markets/fear-and-greed
# - https://edition.cnn.com/politics/president-donald-trump-47
# - https://edition.cnn.com/business/tech/innovate
# - https://edition.cnn.com/interactive/life-but-better/
# - https://edition.cnn.com/us/cnn-investigates
# - https://edition.cnn.com/business/markets-now
# - https://edition.cnn.com/science
# - https://edition.cnn.com/business/media
# - https://edition.cnn.com/travel/news
# - https://edition.cnn.com/weather/video
# - https://edition.cnn.com/business/tech
# - https://facebook.com/CNN
# - https://edition.cnn.com/audio/podcasts/the-assignment
# - https://edition.cnn.com/world/europe/ukraine
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_attached_to_user_prompt(url)}
        ],
        response_format={"type": "json_object"},        
    )
    result = response.choices[0].message.content
    links = json.loads(result)
    return links

# %%
selected_links = select_relevant_links("https://edition.cnn.com")
# print(json.dumps(selected_links, indent=2))

md_text = "\n".join(
    [f"- [{link['type']}]({link['url']})" for link in selected_links["relevant_links"]]
)

display(Markdown(md_text))
# Out:
# - [about page](https://edition.cnn.com/about)
# - [business page](https://edition.cnn.com/business)
# - [elections page](https://edition.cnn.com/election/2026/04/15/world/live-news/iran-war-blockade-us-trump)
# - [markets page](https://edition.cnn.com/markets/premarkets)
# - [profile page](https://edition.cnn.com/profiles/cnn-leadership)
# - [sciences page](https://edition.cnn.com/science/unearthed)
# - [entertainment page](https://edition.cnn.com/entertainment)

# %% [markdown]
# ##### STEP 2: ASSEMBLE ALL THE DETAILS INTO ANOTHER PROMPT TO OLLAMA

# %%
def fetch_page_and_all_its_relevant_link(url):
    page_content = fetch_page_content(url)
    relevant_links = select_relevant_links(url)

    result = f"Page content: {page_content}\n\nRelevant links:\n"
    for link in relevant_links.get("relevant_links", []):
        # Handle both single and multiple URLs
        if "url" in link:
            urls = [link["url"]]
        elif "urls" in link:
            urls = link["urls"]
        else:
            continue  # skip if neither key exists

        for u in urls:
            if not u.startswith(("http://", "https://")):
                u = "https://" + u
            result += f"\n\n### Link: {link.get('type','unknown')} ({u})\n"
            result += fetch_page_content(u)

    return result

# %%
print(fetch_page_and_all_its_relevant_link("https://edition.cnn.com"))
# Out:
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title: ABOUT CNN DIGITAL | CNN
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title: CNN Profiles - CNN Leadership | CNN
# Fetched page title: Business News - Latest Headlines on CNN Business | CNN Business
# Fetched page title: Science | CNN
# Fetched page title: Weather and forecasts | CNN
# Fetched page title: World news - breaking news, video, headlines and opinion | CNN
# Fetched page title: Politics | CNN Politics
# Page content: Breaking News, Latest News and Videos | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# Download the CNN App
# Download the CNN App
# $117 Picasso
# Powerball
# Maradona trial
# Trump and the Pope
# Israel’s new spymaster
# Antisemitic violence
# King Charles’ US state visit
# Bunk beds on planes
# Andrew Harnik/Getty Images
# As Trump attacks friends and foes, Americans are changing their minds about China
# Jonathan Ernst/Reuters/File
# Israel’s new spymaster is a Netanyahu aide who believed war with Iran would topple the regime
# Christian Mang/Reuters
# German far-right party promises free Russian lessons and ‘remigration’ if elected
# US says blockade of Iranian ports 'fully implemented'
# Show all
# •
# Live Updates
# Marine Traffic
# •
# Live Updates
# Live Updates
# a min ago
# Trump also alluded to further US-Iran talks happening before the ceasefire expires next week
# •
# Analysis
# Analysis
# US allies won’t join Trump’s war — but they can’t escape the fallout
# •
# Video
# 0:59
# Video
# AI is supercharging the US-Iran meme war
# 0:59
# Iranian embassies are flooding social media with viral AI-generated memes mocking President Donald Trump for the Iran war. CNN’s Will Ripley explains how “slopaganda” is accelerating a new kind of information war.
# •
# Analysis
# Analysis
# Why are some ships going through the Strait of Hormuz during a blockade?
# The United States’ blockade of Iranian ports has been “fully implemented” and put a halt to most of Tehran’s economic activity in just a day and a half, the head of US Central Command said Wednesday.
# •
# Video
# 2:40
# Video
# How do shipowners navigate Trump’s blockade?
# 2:40
# Global shipowners are warning it
#
# Relevant links:
#
#
# ### Link: home page (https://edition.cnn.com)
# Breaking News, Latest News and Videos | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# Download the CNN App
# Download the CNN App
# $117 Picasso
# Powerball
# Maradona trial
# Trump and the Pope
# Israel’s new spymaster
# Antisemitic violence
# King Charles’ US state visit
# Bunk beds on planes
# Andrew Harnik/Getty Images
# As Trump attacks friends and foes, Americans are changing their minds about China
# Jonathan Ernst/Reuters/File
# Israel’s new spymaster is a Netanyahu aide who believed war with Iran would topple the regime
# Christian Mang/Reuters
# German far-right party promises free Russian lessons and ‘remigration’ if elected
# US says blockade of Iranian ports 'fully implemented'
# Show all
# •
# Live Updates
# Marine Traffic
# •
# Live Updates
# Live Updates
# a min ago
# Trump also alluded to further US-Iran talks happening before the ceasefire expires next week
# •
# Analysis
# Analysis
# US allies won’t join Trump’s war — but they can’t escape the fallout
# •
# Video
# 0:59
# Video
# AI is supercharging the US-Iran meme war
# 0:59
# Iranian embassies are flooding social media with viral AI-generated memes mocking President Donald Trump for the Iran war. CNN’s Will Ripley explains how “slopaganda” is accelerating a new kind of information war.
# •
# Analysis
# Analysis
# Why are some ships going through the Strait of Hormuz during a blockade?
# The United States’ blockade of Iranian ports has been “fully implemented” and put a halt to most of Tehran’s economic activity in just a day and a half, the head of US Central Command said Wednesday.
# •
# Video
# 2:40
# Video
# How do shipowners navigate Trump’s blockade?
# 2:40
# Global shipowners are warning it
#
# ### Link: about us page (https://edition.cnn.com/about)
# ABOUT CNN DIGITAL | CNN
#
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# US
# Crime & Justice
# Immigration
# Education
# Transportation
# Race & Identity
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Money
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# Videos
# Sports
# NFL
# NBA
# MLB
# WNBA
# Golf
# Soccer
# Tennis
# Motorsport
# College Sports
# Olympics
# Bleacher Report
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Featured
# Shows & Films
# Network TV
# Clips
# CNN Headlines
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# Download the CNN App
# Download the CNN App
# About CNN Worldwide
# CNN Worldwide is the most honored brand in cable news, reaching more individuals on television and online than any other cable news organization in the United States. Globally, people across the world can watch CNN International, which is widely distributed in over 200 countries and territories. CNN Digital is the #1 online news destination, with more unique visitors than any other news source. CNN’s award-winning portfolio includes non-scripted programming from CNN Original Series and CNN Films for broadcast, streaming and distribution across multiple platforms. CNN programming can be found on CNN, CNN International and CNN en Español channels, on the CNN Originals hub on discovery+, on Max and for pay TV subscription via CNN.com, CNN apps and cable operator platforms. Additionally, CNN Newsource is the world’s most extensively utilized news service partnering with over 1,000 local and international news organizations around the world. CNN is a division of Warner Bros Discovery.
# CNN’s Mission
# To Inform, Engage and Empower the World
# We are truth-seekers and storytellers.
# We are journalists, designers and technologists, united by a mission to inform, engage and empower the world.
# We bear witness to history as it unfolds and explain not just what happened, but why, and what it means to you.
# Our products and platforms take you to the farthest corners of the world, and they bring the world to you, delivering content and services that enrich your lives, your families and your communities.
# We are available on more screens in more places than any other news source.
# We stand for excellence in our journalism and our products.
# We are committed to serving you.
# We are CNN.
# What’s On
# The full rundown of all
# CNN daily programming
# .
# Who’s On
# Bios on all of
# CNN’s anchors, correspondents and executives.
# CNN’s Parent Company
# Warner Bros. Discovery, Inc.
# CNN AI Editorial Guiding Princ
#
# ### Link: news home page (https://edition.cnn.com)
# Breaking News, Latest News and Videos | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# Download the CNN App
# Download the CNN App
# $117 Picasso
# Powerball
# Maradona trial
# Trump and the Pope
# Israel’s new spymaster
# Antisemitic violence
# King Charles’ US state visit
# Bunk beds on planes
# Andrew Harnik/Getty Images
# As Trump attacks friends and foes, Americans are changing their minds about China
# Jonathan Ernst/Reuters/File
# Israel’s new spymaster is a Netanyahu aide who believed war with Iran would topple the regime
# Christian Mang/Reuters
# German far-right party promises free Russian lessons and ‘remigration’ if elected
# US says blockade of Iranian ports 'fully implemented'
# Show all
# •
# Live Updates
# Marine Traffic
# •
# Live Updates
# Live Updates
# a min ago
# Trump also alluded to further US-Iran talks happening before the ceasefire expires next week
# •
# Analysis
# Analysis
# US allies won’t join Trump’s war — but they can’t escape the fallout
# •
# Video
# 0:59
# Video
# AI is supercharging the US-Iran meme war
# 0:59
# Iranian embassies are flooding social media with viral AI-generated memes mocking President Donald Trump for the Iran war. CNN’s Will Ripley explains how “slopaganda” is accelerating a new kind of information war.
# •
# Analysis
# Analysis
# Why are some ships going through the Strait of Hormuz during a blockade?
# The United States’ blockade of Iranian ports has been “fully implemented” and put a halt to most of Tehran’s economic activity in just a day and a half, the head of US Central Command said Wednesday.
# •
# Video
# 2:40
# Video
# How do shipowners navigate Trump’s blockade?
# 2:40
# Global shipowners are warning it
#
# ### Link: company profile page (https://edition.cnn.com/profiles/cnn-leadership)
# CNN Profiles - CNN Leadership | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Underscored
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# US
# Crime & Justice
# Immigration
# Education
# Transportation
# Race & Identity
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Money
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# Videos
# Sports
# NFL
# NBA
# MLB
# WNBA
# Golf
# Soccer
# Tennis
# Motorsport
# College Sports
# Olympics
# Bleacher Report
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Watch
# Featured
# Shows & Films
# Network TV
# Clips
# CNN Headlines
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Subscribe
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# Download the CNN App
# Download the CNN App
# CNN Profiles
# Faces of CNN
# |
# Leadership
# |
# A-Z
# CNN Leadership
# CNN
# Kathryn Adams
# Adam Cohn
# Johnita P. Due
# Amy Entelis
# Ye Fan
# Alex MacCallum
# Jai Lennard
# Mike McCarthy
# Ye Fan
# Virginia Moseley
# CNN
# Phil Nelson
# CNN
# Eric Sherling
# Art Streiber
# Mark Thompson
# David Vigilante
# Ad Feedback
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Listen
# Watch
# US
# Crime & Justice
# Immigration
# Education
# Transportation
# Race & Identity
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# CNN Underscored
# Electronics
# Fashion
# Beauty
# Health & Fitness
# Home
# Reviews
# Deals
# Money
# Gifts
# Travel
# Outdoors
# Pets
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# NFL
# NBA
# MLB
# WNBA
# Golf
# Soccer
# Tennis
# Motorsport
# College Sports
# Olympics
# Bleacher Report
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Ha
#
# ### Link: business news homepage (https://edition.cnn.com/business)
# Business News - Latest Headlines on CNN Business | CNN Business
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# Business
# Markets
# Tech
# Media
# Calculators
# Videos
# More
# Markets
# Tech
# Media
# Calculators
# Videos
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# Markets
# Tech
# Media
# Calculators
# Videos
# Follow CNN
# Download the CNN App
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Download the CNN App
# Markets
# DOW
# S&P 500
# NASDAQ
# Hot Stocks
# Fear & Greed Index
# -----
# is driving the US market
# Latest Market News
# IMF sees global oil shortfall this year and warns Iran war could tip world into recession
# Medical scans and chips: the hidden fallout of the Iran war for China
# United buying American would be unlike anything ever seen before
# Hot Stocks
# Something isn't loading properly. Please check back later.
# Ad Feedback
# AFP/Getty Images
# IMF sees global oil shortfall this year and warns Iran war could tip world into recession
# Florence Lo/Reuters/File
# Medical scans and chips: the hidden fallout of the Iran war for China
# Kevin Carter/Getty Images
# United buying American would be unlike anything ever seen before
# Tristan Fewings/Getty Images for Doha Film Festival
# Journalist detained in Kuwait after posting Iran war video, advocates say
# George Walker IV/AP/File
# Powerball is going international in an effort to build larger jackpots that draw more players
# Kylie Cooper/Reuters
# Suspect in attack at Sam Altman’s home held without bail
# Ben Margot/AP
# NFL reporter Dianna Russini exits The Athletic amid probe over photos with Patriots coach
# Brendan McDermid/Reuters
# Confirmation hearing set for Trump’s Fed chair nominee
# Gene J. Puskar/AP
# Pittsburgh Post-Gazette rescued from shutdown by last-minute sale
# Olena  Malik/Moment RF/Getty Images
# Rushing to file your taxes? Don’t rely on AI for help, plus other last-minute tips
# Mario Tama/Getty Images
# Wholesale inflation rose in March to three year-high
# Salwan Georges/Bloomberg/Getty Images
# The economic game of chicken between Iran and the US is about to
#
# ### Link: science and technology section (https://edition.cnn.com/science)
# Science | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# Science
# Space
# Life
# Unearthed
# More
# Space
# Life
# Unearthed
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# Space
# Life
# Unearthed
# Follow CNN
# Download the CNN App
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Download the CNN App
# Science
# Julien Benoit
# This 250-million-year-old fossil proves mammal ancestors laid eggs
# Panthera Honduras
# First ‘cloud jaguar’ spotted in 10 years sparks hope in Honduras
# Ronaldo Schemidt/AFP/Getty Images
# What the Artemis II crew shared in first remarks after return to Earth
# NASA
# 5 takeaways from NASA’s biggest test in decades
# NASA
# Get caught up on the Artemis II crew’s moon journey. What’s happened so far and what’s next
# NASA
# Heading home: The riskiest part of the Artemis II moon mission is still ahead
# NASA
# Why NASA sent ‘organ chips’ of the Artemis II crew into space
# Isaac Watson/NASA
# The Artemis II astronauts are heading home. The biggest risks could still lie ahead
# Ad Feedback
# University of Reading
# The ‘oldest octopus’ in the world isn’t an octopus after all, scientists find
# NASA
# Highlights from Artemis II reveal life in space is even weirder than we thought
# Editor's picks
# Photo Illustration by Alberto Mier/CNN/Universal History Archive/Getty Images; Gillian Pullinger/Alamy Stock Photo; Will Dax/Solent News/Shutterstock
# Jane Austen’s cause of death has remained a mystery. But her letters and books offer clues
# Donaldson Collection/Michael Ochs Archives/Getty Images
# An object in a satellite image defies explanation. Could it solve one of aviation’s greatest mysteries?
# Rick Guidice/NASA
# Two billionaires have very different — and equally wild — visions of a future in space. Is either possible?
# Susanne Muth/Dirk Mariaschk/Elis Ruhemann/Pompeii Reset Project/Humboldt University of Berlin
# An ancient stone staircase seemed to lead nowhere. Now it’s revealing the ‘lost Pompeii’
# Ad Feedback
# Space
# Show all
# NASA
# ‘It really bent your mind’: The life-altering phenomenon astronaut
#
# ### Link: weather section (https://edition.cnn.com/weather)
# Weather and forecasts | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# Weather
# Video
# Climate
# More
# Video
# Climate
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# Video
# Climate
# Follow CNN
# Download the CNN App
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Download the CNN App
# Atlanta, GA
# more weather
# C°
# F°
# Today
# 10 Day
# 5 Day
# Feels like
# °
# High
# °
# Low
# °
# Sunrise
# Sunrise
# Sunset
# Sunset
# Wind
# Wind
# Humidity
# Humidity
# Pressure
# Pressure
# Something went wrong
# We're unable to load the latest data. Please check back soon.
# Location not found
# We're unable to find your location. Please try again.
# You're offline
# It looks like you're not connected to the internet. Check your network settings; then try again.
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# ° /
# °
# Weather
# MyRadar/Jordan Hall
# Tornadoes, huge hail tear through Wisconsin and Iowa as multi-day severe storm threat continues
# Charlie Riedel/AP
# Tornado threat ramps up across central US a day after destructive tornadoes in Kansas
# CNN
# Tracking destructive and deadly tornadoes in the US, in maps and charts
# WxChasing
# What is a severe thunderstorm?
# Stephen Lam/San Francisco Chronicle/Getty Images
# Over a month’s worth of rain has fallen on parts of Hawaii as a storm threatens flooding
# Handout/Getty Images South America/Getty Images
# The first predictions for hurricane season are in and El Niño’s fingerprints are all over it
# Kevin Carter/Getty Images
# A Super El Niño is coming. Here’s how a hotter ocean could change the weather near you
# Ad Feedback
# Brandon Bell/Getty Images
# An El Niño-less summer is coming. Here’s what that could mean for the US
# Michael Ciaglo/Getty Images
# A plant that’s everywhere is fueling a growing risk of wildfire disaster
# Climate
# Show all
# Getty Images
# These two iconic polar species have been driven to endangered status by a warming planet
# RJ Sangosti/The /Denver Post/Getty Images
# A freakishly dry spring is literally changing the landscape in Colorado
# Nicolas Economou/Reuters
# ‘Like relying on a
#
# ### Link: world news homepage (https://edition.cnn.com/world)
# World news - breaking news, video, headlines and opinion | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# More
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# Follow CNN
# Download the CNN App
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Download the CNN App
# World
# •
# Live Updates
# •
# Live Updates
# Kawnat Haju/AFP/Getty Images
# Live Updates
# by multiple CNN reporters
# a min ago
# US says blockade of Iranian ports ‘fully implemented’ as Trump hints at further peace talks
# Christian Mang/Reuters
# ‘Remigration’ and Russian lessons: German far-right party promises radical measures if elected
# Lisa Kristine
# Guest essay: Children toiling on a trash mountain spotlight the blurred line between informal and forced labor
# CNN
# Why are some ships going through the Strait of Hormuz during a blockade?
# Andrew Harnik/Getty Images
# As Trump attacks friends and foes, Americans are changing their minds about China
# Munir Uz Zaman/AFP/Getty Images
# Around 250 missing after Rohingya boat capsizes in Andaman Sea, UN agencies say
# Photo Illustration by Jason Lancaster/CNN/MADI/Getty Images
# ‘Colossal’ pressure: How Russia is targeting university students for military recruitment
# Soo-hyeon Kim/Reuters
# Why K-pop idols wear Acubi: The rise of Korean quiet cool
# Mevlut Bayraktar/AP
# Gunman opens fire at high school in Turkey, wounding at least 16
# Bernadett Szabo/Reuters
# Orbán’s defeat is also a blow to his ally Netanyahu
# Getty Images
# China has so far weathered the historic oil crisis. But as Xi prepares to meet Trump, costs are starting to grow
# Andrej Ivanov/AFP/Getty Images
# Canada’s Carney secures stronger mandate for pushing back against Trump
# Amarjeet Kumar Singh/Anadolu/Getty Images
# Economists are putting a price on the Iran war fallout in Asia. It doesn’t
#
# ### Link: politics homepage (https://edition.cnn.com/politics)
# Politics | CNN Politics
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# More
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics you follow
# Sign out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Follow CNN Politics
# Download the CNN App
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# Elections 2026
# Trump
# Facts First
# CNN Polls
# Redistricting Tracker
# Epstein Files
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# Featured
# CNN Fast
# Shows A-Z
# CNN 10
# CNN TV Schedule
# Listen
# All There Is with Anderson Cooper
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# Terms of Service with Clare Duffy
# CNN 5 Things
# All CNN Podcasts
# Games
# Daily Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Download the CNN App
# Politics
# Latest Headlines
# Justin Sullivan/Getty Images
# Gavin Newsom faces growing pressure to intervene in a scrambled California governor’s race
# Julia Demaree Nikhinson/AP
# Worried about the midterms, Republicans mobilize rural Virginia voters against redistricting
# CNN
# A pair of resignations and a swearing in widen Johnson’s narrow House majority, but it could be short-lived
# Getty Images/Reuters
# Swalwell and Gonzales resign from Congress under threat of expulsion
# Heather Diehl/Getty Images/File
# Justice Department moves to dismiss Proud Boys and Oath Keepers’ seditious conspiracy convictions
# Bill Clark/CQ-Roll Call, Inc./Getty Images/File
# Historians suing Trump administration say National Archives won’t commit to preserving presidential records during lawsuit
# CNN
# Emotional Gallego says he heard ‘rumors’ of ‘flirty’ behavior by Swalwell but denies knowledge of sexual assault allegations
# Julia Demaree Nikhinson/AP
# Republicans’ big 2026 problem: An unhinged Trump who doesn’t seem to care about them
# Analysis
# Brendan Smialowski/AFP/Getty Images
# US allies won’t join Trump’s war — but they can’t escape the fallout
# Reuters
# Will Trump get a worse Iran deal than Obama? Here’s what to know
# Win McNamee/Getty Images
# Iran crisis epitomizes a world increasingly resistant to Trump’s demands
# Jose Luis Magana/AP
# Trump’s strait blockade risks another serious blow to the global economy
# Win McNamee/Getty Images
# This Bernie Sanders-backed idea is connecting Democrats winning midterm primaries
# Ellie Stub

# %%
brochure_system_prompt = """
You are an assistant that analyzes the contents of several relevant pages from a company website
and creates a short brochure about the company for prospective customers, investors and recruits.
Respond in markdown without code blocks.
Include details of company culture, customers and careers/jobs if you have the information.
"""

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"""
You are looking at a company called: {company_name}
Here are the contents of its landing page and other relevant pages;
use this information to build a short brochure of the company in markdown without code blocks.\n\n
"""
    user_prompt += fetch_page_and_all_its_relevant_link(url)
    user_prompt += user_prompt[:7000]
    return user_prompt

# %%
get_brochure_user_prompt("CNN", "https://edition.cnn.com")
# Out:
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title: ABOUT CNN DIGITAL | CNN
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title
nChristian Mang/Reuters\nGerman far-right party promises free Russian lessons and ‘remigration’ if elected\nUS says blockade of Iranian ports 'fully implemented'\nShow\xa0all\n•\nLive Updates\nMarine Traffic\n•\nLive Updates\nLive Updates\na min ago\nTrump also alluded to further US-Iran talks happening before the ceasefire expires next week\n•\nAnalysis\nAnalysis\nUS allies won’t join Trump’s war — but they can’t escape the fallout\n•\nVideo\n0:59\nVideo\nAI is supercharging the US-Iran meme war\n0:59\nIranian embassies are flooding social media with viral AI-generated memes mocking President Donald Trump for the Iran war. CNN’s Will Ripley e ...

# %%
def create_brochure(company_name, url):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("CNN", "https://edition.cnn.com")
# Out:
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title: Investing | CNN Business
# Fetched page title: Tennis | CNN
# Fetched page title: Life | CNN
# Fetched page title: CNN 5 Things - Podcast on CNN Podcasts
# Fetched page title: Sudoku
# Fetched page title: Sleep: Life, But Better | CNN
# Fetched page title: Election 2024: Campaign news, presidential polls and results | CNN Politics
# Fetched page title: Business News - Latest Headlines on CNN Business | CNN Business
# Fetched page title: CNN Profiles - CNN Leadership | CNN
# Fetched page title: Jumble Crossword
# Fetched page title: Accessibility Video & Closed Captioning for IP-delivered Video | CNN
# Fetched page title: CNN Business Nightcap | CNN
# Fetched page title: Pre-market Stock Trading | CNN
# Fetched page title: Sudoku
# Fetched page title: The Assignment with Audie Cornish - Podcast on CNN Podcasts
# Fetched page title: Election 2024: Campaign news, presidential polls and results | CNN Politics
# Fetched page title: Golf | CNN
# Fetched page title: Chasing Life with Dr. Sanjay Gupta - Podcast on CNN Podcasts
# Here is a short brochure about CNN in markdown:
#
# **Welcome to CNN**
# =====================
#
# We are a leading international news organization, providing breaking news, analysis, and commentary on global events.
#
# **About Us**
# -------------
#
# * We value your feedback: please take our ad feedback survey
# * Providing accurate and unbiased reporting from around the world
# * Bringing you live updates and breaking news as it happens
# * Covering politics, business, entertainment, sports, and more
#
# **What We Do**
# --------------
#
# * Breaking News: stay up-to-date with the latest developments
# * Latest News: find in-depth coverage of global news and events
# * Analysis and Commentary: expert insights on politics, business, and more
# * Special Features: explore our investigative reports, documentaries, and podcasts
# * TV Schedule: watch live CNN and CNN International programming
#
# **About Your Account**
# --------------------
#
# * Manage your account settings and preferences
# * Sign in to access exclusive content and features
# * Get notified of breaking news and updates from around the world
#
# **Follow Us**
# -------------
#
# * Download our mobile app for easy access to news on-the-go
# * Subscribe to our newsletters and podcasts
# * Follow us on social media for real-time updates and discussion

# %%
def stream_brochure(company_name, url):
    stream = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": brochure_system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
        ],
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        content = chunk.choices[0].delta.get("content", "")
        response += content
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("CNN", "https://edition.cnn.com")
# Out:
# Fetched page title: Breaking News, Latest News and Videos | CNN
# Fetched page title: ABOUT CNN DIGITAL | CNN
# Fetched page title: No Title
# Fetched page title: Business News - Latest Headlines on CNN Business | CNN Business
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 stream_brochure("CNN", "https://edition.cnn.com")
#
# Cell In[59], line 6, in stream_brochure(company_name, url)
#       2     stream = client.chat.completions.create(
#       3         model=model,
#       4         messages=[
#       5             {"role": "system", "content": brochure_system_prompt},
# ----> 6             {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
#       7         ],
#       8         stream=True
#       9     )
#
# Cell In[50], line 7, in get_brochure_user_prompt(company_name, url)
#       3 You are looking at a company called: {company_name}
#       4 Here are the contents of its landing page and other relevant pages;
#       5 use this information to build a short brochure of the company in markdown without code blocks.\n\n
#       6 """
# ----> 7     user_prompt += fetch_page_and_all_its_relevant_link(url)
#       8     user_prompt += user_prompt[:7000]
#       9     return user_prompt
#
# Cell In[53], line 19, in fetch_page_and_all_its_relevant_link(url)
#      15         for u in urls:
#      16             if not u.startswith(("http://", "https://")):
#      17                 u = "https://" + u
#      18             result += f"\n\n### Link: {link.get('type','unknown')} ({u})\n"
# ---> 19             result += fetch_page_content(u)
#      20
#      21     return result
#
# File d:\Private\LLM_Engineering\week1\scraper.py:11, in fetch_page_content(url)
#       9 def fetch_page_content(url):
#      10     """Fetches the content of a web page given its URL. Truncate to 4,000 characters."""
# ---> 11     response = requests.get(url, headers=HEADERS)
#      12     soup = BeautifulSoup(response.content, "html.parser")
#      13     title = soup.title.string if soup.title else "No Title"
#
# File d:\Private\LLM_Engineering\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\Private\LLM_Engineering\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\Private\LLM_Engineering\.venv\Lib\site-packages\requests\sessions.py:578, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     565 # Create the Request.
#     566 req = Request(
#     567     method=method.upper(),
#     568     url=url,
#    (...)    576     hooks=hooks,
#     577 )
# --> 578 prep = self.prepare_request(req)
#     580 proxies = proxies or {}
#     582 settings = self.merge_environment_settings(
#     583     prep.url, proxies, stream, verify, cert
#     584 )
#
# File d:\Private\LLM_Engineering\.venv\Lib\site-packages\requests\sessions.py:487, in Session.prepare_request(self, request)
#     484     auth = get_netrc_auth(request.url)
#     486 p = PreparedRequest()
# --> 487 p.prepare(
#     488     method=request.method.upper(),
#     489     url=request.url,
#     490     files=request.files,
#     491     data=request.data,
#     492     json=request.json,
#     493     headers=merge_setting(
#     494         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     495     ),
#     496     params=merge_setting(request.params, self.params),
#     497     auth=merge_setting(auth, self.auth),
#     498     cookies=merged_cookies,
#     499     hooks=merge_hooks(request.hooks, self.hooks),
#     500 )
#     501 return p
#
# File d:\Private\LLM_Engineering\.venv\Lib\site-packages\requests\models.py:369, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     366 """Prepares the entire request with the given parameters."""
#     368 self.prepare_method(method)
# --> 369 self.prepare_url(url, params)
#     370 self.prepare_headers(headers)
#     371 self.prepare_cookies(cookies)
#
# File d:\Private\LLM_Engineering\.venv\Lib\site-packages\requests\models.py:446, in PreparedRequest.prepare_url(self, url, params)
#     440     raise MissingSchema(
#     441         f"Invalid URL {url!r}: No scheme supplied. "
#     442         f"Perhaps you meant https://{url}?"
#     443     )
#     445 if not host:
# --> 446     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#     448 # In general, we want to try IDNA encoding the hostname if the string contains
#     449 # non-ASCII characters. This allows users to automatically get the correct IDNA
#     450 # behaviour. For strings containing only ASCII characters, we need to also verify
#     451 # it doesn't start with a wildcard (*), before allowing the unencoded hostname.
#     452 if not unicode_is_ascii(host):
#
# InvalidURL: Invalid URL 'https://': No host supplied
